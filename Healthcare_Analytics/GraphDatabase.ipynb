# %% [markdown]
# ### **Assignment Neo4j_ Gauthami Kuravi**

# %% [markdown]
# ### 1.Load MSHI data into Noe4j (mshi, mshi1 and mshi2 files)

# %%
import os
os.getcwd()
#os.chdir(r'C:\Users\skura\Desktop\HAP\NEO4J')

from IPython.display import Image
Image(filename='graph.PNG')

# %% [markdown]
# ### 2.What competencies are covered in HAP 730?

# %% [markdown]
#  **code: match(n:Course {code:"HAP 730"})-[:Skill]-(m:Competency) return m,n;**

# %%
Image(filename='graph2.PNG')

# %% [markdown]
# ### 3.What are prerequisites to HAP 880? List both direct and indirect prerequisites.

# %% [markdown]
# **match (m:Course)-[*]->(n:Course {code:'HAP 880'}) return m,n**

# %%
Image(filename='graph3.PNG')

# %% [markdown]
# ### 4. Load hap780 data file on top of the MSHI database, to include all courses but also skills within hap 780. Design appropriate relationships that need to be included to make the graph connected

# %% [markdown]
# **load csv with headers from "file:///hap780.csv" as l
#   merge (c1:Competency {code:l.c1})
#   merge (c2:Competency {code:l.c2})
#   with c1, c2, l
#   create (c1)-[s:Skill {included:l.Skill}]->(c2)**
#   **match (n {code:"HAP 780"})-[]-(m) return (n), (m)**

# %%
Image(filename='graph4.PNG')
